# %%
import pandas as pd

# %%
# !ls
# Out:
# 10082019-annual-report-on-student-discipline-mf-redacted-for-review.xlsx
# 10102019-annual-report-on-student-recidivists-mf-redacted-for-review 2.xlsx
# 10102019-annual-report-on-student-recidivists-mf-redacted-for-review.xlsx
# 10102019-annual-report-on-student-recidivists-mf-redacted-for-review.xlsx.cpgz
# 2013_-_2018_Demographic_Snapshot_School.csv
# 2019-public-data-file_parent.xlsx
# 2019-public-data-file_student.xlsx
# 2019-public-data-file_teacher.xlsx
# KGIA.ipynb
# README.md
# demographic-snapshot-2014-15-to-2018-19-(public).xlsx

# %%
#Demographics

# %%
df = pd.read_csv('2013_-_2018_Demographic_Snapshot_School.csv')

# %%
df.dtypes
# Out:
# DBN                                            object
# School Name                                    object
# Year                                           object
# Total Enrollment                                int64
# Grade PK (Half Day & Full Day)                  int64
# Grade K                                         int64
# Grade 1                                         int64
# Grade 2                                         int64
# Grade 3                                         int64
# Grade 4                                         int64
# Grade 5                                         int64
# Grade 6                                         int64
# Grade 7                                         int64
# Grade 8                                         int64
# Grade 9                                         int64
# Grade 10                                        int64
# Grade 11                                        int64
# ...

# %%
df[df['School Name'].str.contains('Khalil')][['School Name','Year','% Female', '% Male', '% Asian', '% Black', '% Hispanic','% White','% Students with Disabilities', '% English Language Learners' ]]
# Out:
#                               School Name     Year  % Female  % Male  % Asian  \
# 3880  Khalil Gibran International Academy  2013-14      46.4    53.6     11.3
# 3881  Khalil Gibran International Academy  2014-15      42.5    57.5     15.5
# 3882  Khalil Gibran International Academy  2015-16      44.4    55.6     16.8
# 3883  Khalil Gibran International Academy  2016-17      44.8    55.2     16.8
# 3884  Khalil Gibran International Academy  2017-18      47.8    52.2     17.8
#
#       % Black  % Hispanic  % White  % Students with Disabilities  \
# 3880     56.7         6.2     23.7                          20.6
# 3881     48.3         6.3     27.6                          17.8
# 3882     39.7         5.6     34.5                          15.5
# 3883     35.4         6.7     36.6                          14.2
# 3884     38.9         7.8     30.7                          17.4
#
#       % English Language Learners
# 3880                         29.9
# 3881                         32.8
# ...

# %%
#Gender

# %%
#https://tools.nycenet.edu/guide/2019/#dbn=15K592&report_type=HS ; 55%male, 45% female - has this trend changed over time?

# %%
#School Discipline

# %%
df2 = pd.read_excel('10082019-annual-report-on-student-discipline-mf-redacted-for-review.xlsx')

# %%
df2.dtypes
# Out:
# DBN                                   object
# LOCATION NAME                         object
# LOCATION CATEGORY                     object
# ADMINISTRATIVE DISTRICT              float64
# REMOVALS                              object
# PRINCIPAL                             object
# SUPERINTENDENT                        object
# EXPULSIONS                             int64
# SY1819 TOTAL REMOVALS/SUSPENSIONS     object
# dtype: object

# %%
df2['Location Name']=df2['LOCATION NAME'].dropna()

# %%
df2.loc[df2['LOCATION NAME'] == 'Khalil Gibran International Academy']
# Out:
#         DBN                        LOCATION NAME LOCATION CATEGORY  \
# 777  15K592  Khalil Gibran International Academy       High school
#
#      ADMINISTRATIVE DISTRICT REMOVALS PRINCIPAL SUPERINTENDENT  EXPULSIONS  \
# 777                     15.0        R         R              7           0
#
#     SY1819 TOTAL REMOVALS/SUSPENSIONS                        Location Name
# 777                                10  Khalil Gibran International Academy

# %%
df3 = pd.read_excel('10102019-annual-report-on-student-recidivists-mf-redacted-for-review.xlsx')

# %%
df3.dtypes
# Out:
# Series([], dtype: object)

# %%
df3
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
#idk what's up with that

# %%
#Parent

# %%
df4 = pd.read_excel('2019-public-data-file_parent.xlsx')

# %%
df4
# Out:
#          DBN                                    School Name  \
# 0        NaN                                            NaN
# 1        NaN                                            NaN
# 2     01M015                      P.S. 015 ROBERTO CLEMENTE
# 3     01M019                            P.S. 019 ASHER LEVY
# 4     01M020                           P.S. 020 ANNA SILVER
# ...      ...                                            ...
# 2943    C968        NYLFEL - WILLIAM O'CONNOR SCH - MIDWOOD
# 2944    C989           FIRST FOOT FORWARD - ARTHUR KILL RD.
# 2945    C993  BIRCH FAMILY SERVICES - WESTERN QUEENS CENTER
# 2946    C997           POSITIVE BEGINNINGS, INC. - MAIN ST.
# 2947    C998             SUSAN E. WAGNER - WHITE PLAINS RD.
#
#       Total Parent \nResponse Rate  Total Teacher Response Rate  \
# 0                              NaN                          NaN
# 1                              NaN                          NaN
# ...

# %%
df4['Total Teacher Response Rate'].mean()
# Out:
# 84.11297950604309

# %%
df4['Total Teacher Response Rate'].median()
# Out:
# 90.0

# %%
df4['Total Student Response Rate'].mean()
# Out:
# 81.59783588818756

# %%
df4['Total Student Response Rate'].median()
# Out:
# 89.0

# %%
df4['Effective School Leadership Score'].mean()
# Out:
# 3.6147876923076923

# %%
df4['Effective School Leadership Score'].median()
# Out:
# 3.64

# %%
df4.loc[df4['School Name'] == 'KHALIL GIBRAN INTERNATIONAL ACADEMY']
# Out:
#         DBN                          School Name  \
# 780  15K592  KHALIL GIBRAN INTERNATIONAL ACADEMY
#
#      Total Parent \nResponse Rate  Total Teacher Response Rate  \
# 780                          43.0                         77.0
#
#      Total Student Response Rate  Collaborative Teachers Score  \
# 780                         57.0                           3.6
#
#      Effective School Leadership Score  Rigorous Instruction Score  \
# 780                               3.39                        3.36
#
#      Supportive Environment Score  Strong Family-Community Ties Score  \
# 780                           NaN                                3.07
#
#      Trust Score
# 780         3.92

# %%
#Student

# %%
df5 = pd.read_excel('2019-public-data-file_parent.xlsx')

# %%
df5.loc[df5['School Name'] == 'KHALIL GIBRAN INTERNATIONAL ACADEMY']
# Out:
#         DBN                          School Name  \
# 780  15K592  KHALIL GIBRAN INTERNATIONAL ACADEMY
#
#      Total Parent \nResponse Rate  Total Teacher Response Rate  \
# 780                          43.0                         77.0
#
#      Total Student Response Rate  Collaborative Teachers Score  \
# 780                         57.0                           3.6
#
#      Effective School Leadership Score  Rigorous Instruction Score  \
# 780                               3.39                        3.36
#
#      Supportive Environment Score  Strong Family-Community Ties Score  \
# 780                           NaN                                3.07
#
#      Trust Score
# 780         3.92

# %%
# The building isn't accessible according to schools.nyc.gov/schools/K592; but I saw a ramp through the back?

# %%
#graduation rate

# %%
# !ls
# Out:
# 10082019-annual-report-on-student-discipline-mf-redacted-for-review.xlsx
# 10102019-annual-report-on-student-recidivists-mf-redacted-for-review 2.xlsx
# 10102019-annual-report-on-student-recidivists-mf-redacted-for-review.xlsx
# 10102019-annual-report-on-student-recidivists-mf-redacted-for-review.xlsx.cpgz
# 2013_-_2018_Demographic_Snapshot_School.csv
# 201819_hs_sqr_results.xlsx
# 2019-public-data-file_parent.xlsx
# 2019-public-data-file_student.xlsx
# 2019-public-data-file_teacher.xlsx
# KGIA.ipynb
# README.md
# demographic-snapshot-2014-15-to-2018-19-(public).xlsx

# %%
df6 = pd.read_excel('201819_hs_sqr_results.xlsx')

# %%
df6.drop([0,1])
# Out:
#      Unnamed: 0 Unnamed: 1  Unnamed: 2 Unnamed: 3  \
# 2           NaN        NaN         NaN        DBN
# 3           NaN        NaN         NaN        NaN
# 4           NaN        NaN         NaN     01M292
# 5           NaN        NaN         NaN     01M448
# 6           NaN        NaN         NaN     01M450
# ..          ...        ...         ...        ...
# 485         NaN        NaN         NaN     84X581
# 486         NaN        NaN         NaN     84X597
# 487         NaN        NaN         NaN     84X610
# 488         NaN        NaN         NaN     84X703
# 489         NaN        NaN         NaN     84X704
#
#                                             Unnamed: 4   Unnamed: 5  \
# 2                                          School Name  School Type
# 3                                                  NaN          NaN
# 4                           Orchard Collegiate Academy  High School
# 5                  University Neighborhood High School  High School
# ...

# %%
df6.columns = df6.iloc[2]

# %%
df6
# Out:
# 2    NaN      NaN  NaN     DBN  \
# 0    NaN  Summary  NaN     NaN
# 1    NaN      NaN  NaN     NaN
# 2    NaN      NaN  NaN     DBN
# 3    NaN      NaN  NaN     NaN
# 4    NaN      NaN  NaN  01M292
# ..   ...      ...  ...     ...
# 485  NaN      NaN  NaN  84X581
# 486  NaN      NaN  NaN  84X597
# 487  NaN      NaN  NaN  84X610
# 488  NaN      NaN  NaN  84X703
# 489  NaN      NaN  NaN  84X704
#
# 2                                          School Name  School Type  \
# 0                                                  NaN          NaN
# 1                                                  NaN          NaN
# 2                                          School Name  School Type
# 3                                                  NaN          NaN
# 4                           Orchard Collegiate Academy  High School
# ..                                                 ...          ...
# 485               South Bronx Community Charter School  High School
# ...

# %%
df6['School Name'] = df6['School Name'].dropna()

# %%
df6.dtypes
# Out:
# 2
# NaN                                                                                               float64
# NaN                                                                                                object
# NaN                                                                                               float64
# DBN                                                                                                object
# School Name                                                                                        object
# School Type                                                                                        object
# Enrollment                                                                                         object
# Rigorous Instruction Rating                                                                        object
# Collaborative Teachers Rating                                                                      object
# ...

# %%
df6[df6['School Name'] == 'Khalil Gibran International Academy']
# Out:
# 2    NaN  NaN  NaN     DBN                          School Name  School Type  \
# 252  NaN  NaN  NaN  15K592  Khalil Gibran International Academy  High School
#
# 2   Enrollment Rigorous Instruction Rating Collaborative Teachers Rating  \
# 252        226              Meeting Target                Meeting Target
#
# 2   Supportive Environment Rating  ... Percent HRA Eligible Percent Asian  \
# 252                Meeting Target  ...                0.792         0.177
#
# 2   Percent Black Percent Hispanic Percent White  \
# 252         0.358             0.08         0.314
#
# 2   Years of principal experience at this school  \
# 252                                          7.9
#
# 2   Percent of teachers with 3 or more years of experience  \
# 252                                                0.6
#
# 2   Student Attendance Rate Percent of Students Chronically Absent  \
# 252                   0.831                                  0.498
#
# 2   Teacher Attendance Rate
# ...

# %%
# nearly 50 percent are chronically absent
